# %%
from rl_qlearning import Q_learning
import matplotlib.pyplot as plt
import gym
# %matplotlib inline

# initialize the environment
env = gym.make('CartPole-v1')

# %%
n = 50 # number of episodes to average

# simulate the Q-learning
rl_qlearning1 = Q_learning(env)
rl_qlearning1.episode = 5000
rl_qlearning1.gamma = 0.9 # discount factor
rl_qlearning1.alpha = 0.1 # learning rate
rl_qlearning1.epsilon = 1 # exploration rate
rl_qlearning1.buckets = 2 # number of buckets
rl_qlearning1.simulate()
y1 = rl_qlearning1.reward_history

rl_qlearning2 = Q_learning(env)
rl_qlearning2.episode = 5000
rl_qlearning2.gamma = 0.9 # discount factor
rl_qlearning2.alpha = 0.1 # learning rate
rl_qlearning2.epsilon = 1 # exploration rate
rl_qlearning2.buckets = 5 # number of buckets
rl_qlearning2.simulate()
y2 = rl_qlearning2.reward_history

rl_qlearning3 = Q_learning(env)
rl_qlearning3.episode = 5000
rl_qlearning3.gamma = 0.9 # discount factor
rl_qlearning3.alpha = 0.1 # learning rate
rl_qlearning3.epsilon = 1 # exploration rate
rl_qlearning3.buckets = 10 # number of buckets
rl_qlearning3.simulate()
y3 = rl_qlearning3.reward_history

y1 = [sum(y1[i:i+n])/n for i in range(0, len(y1), n)]
x1 = range(0,len(y1)*n,n)

y2 = [sum(y2[i:i+n])/n for i in range(0, len(y2), n)]
x2 = range(0,len(y2)*n,n)

y3 = [sum(y3[i:i+n])/n for i in range(0, len(y3), n)]
x3 = range(0,len(y3)*n,n)

# plot the graph
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.legend(['buckets = 2', 'buckets = 5', 'buckets = 10'])
plt.xlabel('Episode')
plt.ylabel('Sum of Rewards in Episode')
plt.title('a) State Space size')
# save the figure
plt.savefig('graph/graph a 5000.png')

# %%
n = 50 # number of episodes to average

# simulate the Q-learning
rl_qlearning4 = Q_learning(env)
rl_qlearning4.episode = 5000
rl_qlearning4.gamma = 0.9 # discount factor
rl_qlearning4.alpha = 0.1 # learning rate
rl_qlearning4.epsilon = 1 # exploration rate
rl_qlearning4.buckets = 10 # number of buckets
rl_qlearning4.simulate()
y1 = rl_qlearning4.reward_history

rl_qlearning5 = Q_learning(env)
rl_qlearning5.episode = 5000
rl_qlearning5.gamma = 0.9 # discount factor
rl_qlearning5.alpha = 0.5 # learning rate
rl_qlearning5.epsilon = 1 # exploration rate
rl_qlearning5.buckets = 10 # number of buckets
rl_qlearning5.simulate()
y2 = rl_qlearning5.reward_history

rl_qlearning6 = Q_learning(env)
rl_qlearning6.episode = 5000
rl_qlearning6.gamma = 0.9 # discount factor
rl_qlearning6.alpha = 0.9 # learning rate
rl_qlearning6.epsilon = 1 # exploration rate
rl_qlearning6.buckets = 10 # number of buckets
rl_qlearning6.simulate()
y3 = rl_qlearning6.reward_history

y1 = [sum(y1[i:i+n])/n for i in range(0, len(y1), n)]
x1 = range(0,len(y1)*n,n)

y2 = [sum(y2[i:i+n])/n for i in range(0, len(y2), n)]
x2 = range(0,len(y2)*n,n)

y3 = [sum(y3[i:i+n])/n for i in range(0, len(y3), n)]
x3 = range(0,len(y3)*n,n)

# plot the graph
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.legend(['learning rate = 0.1', 'learning rate = 0.5', 'learning rate = 0.9'])
plt.xlabel('Episode')
plt.ylabel('Sum of Rewards in Episode')
plt.title('b) Learning Rate')
# save the figure
plt.savefig('graph/graph b 5000.png')

# %%
n = 50 # number of episodes to average

# simulate the Q-learning
rl_qlearning7 = Q_learning(env)
rl_qlearning7.episode = 5000
rl_qlearning7.gamma = 0.1 # discount factor
rl_qlearning7.alpha = 0.1 # learning rate
rl_qlearning7.epsilon = 0.1 # exploration rate
rl_qlearning7.buckets = 10 # number of buckets
rl_qlearning7.simulate()
y1 = rl_qlearning7.reward_history

rl_qlearning8 = Q_learning(env)
rl_qlearning8.episode = 5000
rl_qlearning8.gamma = 0.5 # discount factor
rl_qlearning8.alpha = 0.1 # learning rate
rl_qlearning8.epsilon = 0.1 # exploration rate
rl_qlearning8.buckets = 10 # number of buckets
rl_qlearning8.simulate()
y2 = rl_qlearning8.reward_history

rl_qlearning9 = Q_learning(env)
rl_qlearning9.episode = 5000
rl_qlearning9.gamma = 0.9 # discount factor
rl_qlearning9.alpha = 0.1 # learning rate
rl_qlearning9.epsilon = 0.1 # exploration rate
rl_qlearning9.buckets = 10 # number of buckets
rl_qlearning9.simulate()
y3 = rl_qlearning9.reward_history

y1 = [sum(y1[i:i+n])/n for i in range(0, len(y1), n)]
x1 = range(0,len(y1)*n,n)

y2 = [sum(y2[i:i+n])/n for i in range(0, len(y2), n)]
x2 = range(0,len(y2)*n,n)

y3 = [sum(y3[i:i+n])/n for i in range(0, len(y3), n)]
x3 = range(0,len(y3)*n,n)

# plot the graph
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.legend(['discount factor = 0.1', 'discount factor = 0.5', 'discount factor = 0.9'])
plt.xlabel('Episode')
plt.ylabel('Sum of Rewards in Episode')
plt.title('c) Discount Factor')
# save the figure
plt.savefig('graph/graph c 5000.png')

# %%
n = 50 # number of episodes to average

# simulate the Q-learning
rl_qlearning10 = Q_learning(env)
rl_qlearning10.episode = 5000
rl_qlearning10.gamma = 0.9 # discount factor
rl_qlearning10.alpha = 0.1 # learning rate
rl_qlearning10.epsilon = 0.1 # exploration rate
rl_qlearning10.buckets = 10 # number of buckets
rl_qlearning10.simulate()
y1 = rl_qlearning10.reward_history

rl_qlearning11 = Q_learning(env)
rl_qlearning11.episode = 5000
rl_qlearning11.gamma = 0.9 # discount factor
rl_qlearning11.alpha = 0.1 # learning rate
rl_qlearning11.epsilon = 0.5 # exploration rate
rl_qlearning11.buckets = 10 # number of buckets
rl_qlearning11.simulate()
y2 = rl_qlearning11.reward_history

rl_qlearning12 = Q_learning(env)
rl_qlearning12.episode = 5000
rl_qlearning12.gamma = 0.9 # discount factor
rl_qlearning12.alpha = 0.1 # learning rate
rl_qlearning12.epsilon = 0.9 # exploration rate
rl_qlearning12.buckets = 10 # number of buckets
rl_qlearning12.simulate()
y3 = rl_qlearning12.reward_history

y1 = [sum(y1[i:i+n])/n for i in range(0, len(y1), n)]
x1 = range(0,len(y1)*n,n)

y2 = [sum(y2[i:i+n])/n for i in range(0, len(y2), n)]
x2 = range(0,len(y2)*n,n)

y3 = [sum(y3[i:i+n])/n for i in range(0, len(y3), n)]
x3 = range(0,len(y3)*n,n)

# plot the graph
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.legend(['epsilon = 0.1', 'epsilon = 0.5', 'epsilon = 0.9'])
plt.xlabel('Episode')
plt.ylabel('Sum of Rewards in Episode')
plt.title('d) Epsilon')
# save the figure
plt.savefig('graph/graph d 5000.png')
